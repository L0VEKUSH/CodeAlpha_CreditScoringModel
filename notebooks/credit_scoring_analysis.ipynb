# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pathlib import Path

sns.set_theme(style="whitegrid")

columns = [
    "checking_status",
    "duration",
    "credit_history",
    "purpose",
    "credit_amount",
    "savings_status",
    "employment",
    "installment_rate",
    "personal_status",
    "other_debtors",
    "residence_since",
    "property",
    "age",
    "other_installment_plans",
    "housing",
    "existing_credits",
    "job",
    "num_dependents",
    "own_telephone",
    "foreign_worker",
    "credit_risk"
]

# %%
data_path = Path.cwd() / "data" / "german.data"

if not data_path.exists():
    data_path = Path.cwd().parent / "data" / "german.data"

df = pd.read_csv(
    data_path,
    sep=r"\s+",
    header=None,
    names=columns
)

print("Dataset Shape:", df.shape)

display(df.head())
# Out:
# Dataset Shape: (1000, 21)
#   checking_status  duration credit_history purpose  credit_amount  \
# 0             A11         6            A34     A43           1169
# 1             A12        48            A32     A43           5951
# 2             A14        12            A34     A46           2096
# 3             A11        42            A32     A42           7882
# 4             A11        24            A33     A40           4870
#
#   savings_status employment  installment_rate personal_status other_debtors  \
# 0            A65        A75                 4             A93          A101
# 1            A61        A73                 2             A92          A101
# 2            A61        A74                 2             A93          A101
# 3            A61        A74                 2             A93          A103
# 4            A61        A73                 3             A93          A101
#
#    ...  property age  other_installment_plans housing existing_credits   job  \
# 0  ...      A121  67                     A143    A152                2  A173
# 1  ...      A121  22                     A143    A152                1  A173
# 2  ...      A121  49                     A143    A152                1  A172
# 3  ...      A122  45                     A143    A153                1  A173
# 4  ...      A124  53                     A143    A153                2  A173
#
#   num_dependents  own_telephone foreign_worker credit_risk
# 0              1           A192           A201           1
# 1              1           A191           A201           2
# 2              2           A191           A201           1
# 3              2           A191           A201           1
# 4              2           A191           A201           2
#
# [5 rows x 21 columns]

# %%
print("Dataset Information:")
df.info()

print("\nStatistical Summary:")
display(df.describe(include="all"))

print("\nTarget Distribution:")
print(df["credit_risk"].value_counts())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   checking_status          1000 non-null   str
#  1   duration                 1000 non-null   int64
#  2   credit_history           1000 non-null   str
#  3   purpose                  1000 non-null   str
#  4   credit_amount            1000 non-null   int64
#  5   savings_status           1000 non-null   str
#  6   employment               1000 non-null   str
#  7   installment_rate         1000 non-null   int64
#  8   personal_status          1000 non-null   str
#  9   other_debtors            1000 non-null   str
#  10  residence_since          1000 non-null   int64
#  11  property                 1000 non-null   str
#  12  age                      1000 non-null   int64
#  13  other_installment_plans  1000 non-null   str
#  14  housing                  1000 non-null   str
#  15  existing_credits         1000 non-null   int64
#  16  job                      1000 non-null   str
#  17  num_dependents           1000 non-null   int64
#  18  own_telephone            1000 non-null   str
#  19  foreign_worker           1000 non-null   str
#  20  credit_risk              1000 non-null   int64
# dtypes: int64(8), str(13)
# memory usage: 209.1 KB
#
# Statistical Summary:
#        checking_status     duration credit_history purpose  credit_amount  \
# count             1000  1000.000000           1000    1000    1000.000000
# unique               4          NaN              5      10            NaN
# top                A14          NaN            A32     A43            NaN
# freq               394          NaN            530     280            NaN
# mean               NaN    20.903000            NaN     NaN    3271.258000
# std                NaN    12.058814            NaN     NaN    2822.736876
# min                NaN     4.000000            NaN     NaN     250.000000
# 25%                NaN    12.000000            NaN     NaN    1365.500000
# 50%                NaN    18.000000            NaN     NaN    2319.500000
# 75%                NaN    24.000000            NaN     NaN    3972.250000
# max                NaN    72.000000            NaN     NaN   18424.000000
#
#        savings_status employment  installment_rate personal_status  \
# count            1000       1000       1000.000000            1000
# unique              5          5               NaN               4
# top               A61        A73               NaN             A93
# freq              603        339               NaN             548
# mean              NaN        NaN          2.973000             NaN
# std               NaN        NaN          1.118715             NaN
# min               NaN        NaN          1.000000             NaN
# 25%               NaN        NaN          2.000000             NaN
# 50%               NaN        NaN          3.000000             NaN
# 75%               NaN        NaN          4.000000             NaN
# max               NaN        NaN          4.000000             NaN
#
#        other_debtors  ...  property          age  other_installment_plans  \
# count           1000  ...      1000  1000.000000                     1000
# unique             3  ...         4          NaN                        3
# top             A101  ...      A123          NaN                     A143
# freq             907  ...       332          NaN                      814
# mean             NaN  ...       NaN    35.546000                      NaN
# std              NaN  ...       NaN    11.375469                      NaN
# min              NaN  ...       NaN    19.000000                      NaN
# 25%              NaN  ...       NaN    27.000000                      NaN
# 50%              NaN  ...       NaN    33.000000                      NaN
# 75%              NaN  ...       NaN    42.000000                      NaN
# max              NaN  ...       NaN    75.000000                      NaN
#
#        housing existing_credits   job num_dependents  own_telephone  \
# count     1000      1000.000000  1000    1000.000000           1000
# unique       3              NaN     4            NaN              2
# top       A152              NaN  A173            NaN           A191
# freq       713              NaN   630            NaN            596
# mean       NaN         1.407000   NaN       1.155000            NaN
# std        NaN         0.577654   NaN       0.362086            NaN
# min        NaN         1.000000   NaN       1.000000            NaN
# 25%        NaN         1.000000   NaN       1.000000            NaN
# 50%        NaN         1.000000   NaN       1.000000            NaN
# 75%        NaN         2.000000   NaN       1.000000            NaN
# max        NaN         4.000000   NaN       2.000000            NaN
#
#        foreign_worker  credit_risk
# count            1000  1000.000000
# unique              2          NaN
# top              A201          NaN
# freq              963          NaN
# mean              NaN     1.300000
# std               NaN     0.458487
# min               NaN     1.000000
# 25%               NaN     1.000000
# 50%               NaN     1.000000
# 75%               NaN     2.000000
# max               NaN     2.000000
#
# [11 rows x 21 columns]
# Target Distribution:
# credit_risk
# 1    700
# 2    300
# Name: count, dtype: int64
#
# Missing Values:
# checking_status            0
# duration                   0
# credit_history             0
# purpose                    0
# credit_amount              0
# savings_status             0
# employment                 0
# installment_rate           0
# personal_status            0
# other_debtors              0
# residence_since            0
# property                   0
# age                        0
# other_installment_plans    0
# housing                    0
# existing_credits           0
# job                        0
# num_dependents             0
# own_telephone              0
# foreign_worker             0
# credit_risk                0
# dtype: int64
#
# Duplicate Rows:
# 0

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="credit_risk",
    hue="credit_risk",
    palette="Set2",
    legend=False
)

plt.title("Credit Risk Distribution")
plt.xlabel("Credit Risk")
plt.ylabel("Number of Applicants")
plt.xticks([0, 1], ["Good Risk", "Bad Risk"])

plt.tight_layout()
plt.show()

# %%
output_path = data_path.parent / "credit_data.csv"

df.to_csv(output_path, index=False)

print("Dataset saved successfully!")
print("File:", output_path)
print("Shape:", df.shape)
# Out:
# Dataset saved successfully!
# File: c:\Users\ASUS\Downloads\5th sem\cerificates\CodeAlpha_CreditScoringModel\data\credit_data.csv
# Shape: (1000, 21)
